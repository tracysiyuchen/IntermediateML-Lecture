# %% [markdown]
# ## Demo code for kernel density estimation
#
# This notebook illustrates kernel density estimation, which is basically the same as kernel smoothing
# for regression. The estimator is given by
# $$ {\hat f}(x) = \frac{1}{nh^p} \sum_{i=1}^n K\left( \frac{X_i - x}{h}\right)$$
# where $K(u)$ is a smoothing kernel that integrates to one.
# As in our previous notebook, we show the use of [different kernels](https://en.wikipedia.org/wiki/Kernel_(statistics)#Kernel_functions_in_common_use), illustrating that it's the bandwidth that matters most, not the shape of the kernel.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def boxcar_kernel(u, h):
    return 0.5*np.array(np.fabs(u)/h < 1)

def triangular_kernel(u, h):
    return (1-np.abs(u)/h)*np.array(np.fabs(u)/h < 1)

def gaussian_kernel(u, h):
    return (1./np.sqrt(2*np.pi)) * np.exp(-(u)**2/(2*h**2))

def epanechnikov_kernel(u, h):
    return 0.75 * (1 - u**2/h**2)*np.array(np.fabs(u)/h < 1)

def tricube_kernel(u, h):
    return (70./81) * ((1 - np.abs(u)**3/h**3)**3)*np.array(np.fabs(u)/h < 1)

def kde_with_kernel(kernel, X, x, h):
    K = np.zeros(len(x)*len(X)).reshape(len(x), len(X))
    for j in np.arange(K.shape[1]):
        K[:,j] = kernel(x-X[j], h)
    fhat = (1/h) * np.mean(K, axis=1)
    return fhat

# %% [markdown]
# We read in the [Fiji earthquake data](https://stat.ethz.ch/R-manual/R-devel/library/datasets/html/quakes.html).

# %%
quakes = pd.read_csv('https://raw.githubusercontent.com/YData123/sds365-fa25/main/demos/smoothing/fijiquakes.dat', sep='\s+')
quakes
# Out:
#      Obs.    lat    long  depth  mag  stations
# 0       1 -20.42  181.62    562  4.8        41
# 1       2 -20.62  181.03    650  4.2        15
# 2       3 -26.00  184.10     42  5.4        43
# 3       4 -17.97  181.66    626  4.1        19
# 4       5 -20.42  181.96    649  4.0        11
# ..    ...    ...     ...    ...  ...       ...
# 995   996 -25.93  179.54    470  4.4        22
# 996   997 -12.28  167.06    248  4.7        35
# 997   998 -20.13  184.20    244  4.5        34
# 998   999 -17.40  187.80     40  4.5        14
# 999  1000 -21.59  170.56    165  6.0       119
#
# [1000 rows x 6 columns]

# %%
X = quakes['depth']
x = np.linspace(-100, 800, 500)

fhat_gaussian = kde_with_kernel(gaussian_kernel, X, x, 20)
fhat_tricube = kde_with_kernel(tricube_kernel, X, x, 50)
fhat_epanech = kde_with_kernel(epanechnikov_kernel, X, x, 40)
fhat_box = kde_with_kernel(boxcar_kernel, X, x, 35)
fhat_triangle = kde_with_kernel(triangular_kernel, X, x, 45)

plt.figure(figsize=(12, 8))

#plt.plot(x, fhat_box, label='boxcar')
plt.plot(x, fhat_triangle, label='triangular')
plt.plot(x, fhat_gaussian, label='gaussian')
plt.plot(x, fhat_tricube, label='tricube')
plt.plot(x, fhat_epanech, label='epanechnikov')

plt.xlabel('depth of earthquake')
plt.ylabel('probability density')
plt.legend()

## kernel doesn't matter but the bandwidth

# %% [markdown]
# Below we replicate a fancy way of visualizing the earthquake data, from [this site](https://towardsdatascience.com/how-to-make-stunning-interactive-maps-with-python-and-folium-in-minutes-e3aff3b0ed43).

# %% [markdown]
# kernel doesn't matter but the bandwidth

# %%
#!pip install folium
import folium

def generate_color(magnitude):
    if magnitude <= 5:
        c_outline, c_fill = '#ffda79', '#ffda79'
        m_opacity, f_opacity = 0.2, 0.1
    else:
        c_outline, c_fill = '#c0392b', '#e74c3c'
        m_opacity, f_opacity = 1, 1
    return c_outline, c_fill, m_opacity, f_opacity

def generate_popup(magnitude, depth):
    return f'''<strong>Magnitude:</strong> {magnitude}<br><strong>Depth:</strong> {depth} km'''

quake_map = folium.Map(
    location=[-16.495477, 174.9663341],
    zoom_start=4,
    tiles='Stamen Terrain',
    width=1024,
    height=600,
    attr='attribution'
)

for _, row in quakes.iterrows():
    c_outline, c_fill, m_opacity, f_opacity = generate_color(row['mag'])
    folium.CircleMarker(
        location=[row['lat'], row['long']],
        popup=generate_popup(row['mag'], row['depth']),
        color=c_outline,
        fill=True,
        fillColor=c_fill,
        opacity=m_opacity,
        fillOpacity=f_opacity,
        radius=(row['mag'] ** 3) / 15
    ).add_to(quake_map)

quake_map
# Out:
# Requirement already satisfied: folium in /Users/lafferty/opt/anaconda3/envs/iML/lib/python3.8/site-packages (0.18.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/lafferty/opt/anaconda3/envs/iML/lib/python3.8/site-packages (from folium) (3.0.1)
# Requirement already satisfied: requests in /Users/lafferty/opt/anaconda3/envs/iML/lib/python3.8/site-packages (from folium) (2.26.0)
# Requirement already satisfied: numpy in /Users/lafferty/opt/anaconda3/envs/iML/lib/python3.8/site-packages (from folium) (1.21.1)
# Requirement already satisfied: xyzservices in /Users/lafferty/opt/anaconda3/envs/iML/lib/python3.8/site-packages (from folium) (2025.4.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/lafferty/opt/anaconda3/envs/iML/lib/python3.8/site-packages (from folium) (0.8.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/lafferty/opt/anaconda3/envs/iML/lib/python3.8/site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lafferty/opt/anaconda3/envs/iML/lib/python3.8/site-packages (from requests->folium) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lafferty/opt/anaconda3/envs/iML/lib/python3.8/site-packages (from requests->folium) (3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/lafferty/opt/anaconda3/envs/iML/lib/python3.8/site-packages (from requests->folium) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/lafferty/opt/anaconda3/envs/iML/lib/python3.8/site-packages (from requests->folium) (2.0.0)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46345fafd44676304b64f06fabf1d0a7 {
#                     position: relative;
#                     width: 1024.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46345fafd44676304b64f06fabf1d0a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46345fafd44676304b64f06fabf1d0a7 = L.map(
#                 &quot;map_46345fafd44676304b64f06fabf1d0a7&quot;,
#                 {
#                     center: [-16.495477, 174.9663341],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51f2cb7f251e573c36b2f2f97a6ec00b = L.tileLayer(
#                 &quot;Stamen Terrain&quot;,
#                 {&quot;attribution&quot;: &quot;attribution&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_51f2cb7f251e573c36b2f2f97a6ec00b.addTo(map_46345fafd44676304b64f06fabf1d0a7);
#
#
#             var circle_marker_a20acc497e70f7962ad3941c719f4449 = L.circleMarker(
#                 [-20.42, 181.62],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffda79&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffda79&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 7.372799999999999, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_46345fafd44676304b64f06fabf1d0a7);
#
#
#         var popup_f4df5e8899727974095914b495f8933a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_588cac9546312fe3c80ef721a09c2def = $(`&lt;div id=&quot;html_588cac9546312fe3c80ef721a09c2def&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Magnitude:&lt;/strong&gt; 4.8&lt;br&gt;&lt;strong&gt;Depth:&lt;/strong&gt; 562.0 km&lt;/div&gt;`)[0];
#                 popup_f4df5e8899727974095914b495f8933a.setContent(html_588cac9546312fe3c80ef721a09c2def);
#
#
#
#         circle_marker_a20acc497e70f7962ad3941c719f4449.bindPopup(popup_f4df5e8899727974095914b495f8933a)
#         ;
#
#
#
#
#             var circle_marker_2a7e158ba487dd166bffd11f1599ee59 = L.circleMarker(
#                 [-20.62, 181.03],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffda79&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffda79&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 4.9392000000000005, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_46345fafd44676304b64f06fabf1d0a7);
#
#
#         var popup_70924fe2f417859272214e4aff50fa13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8fa93d189d6b5b2ebe89313175dcf0c1 = $(`&lt;div id=&quot;html_8fa93d189d6b5b2ebe89313175dcf0c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Magnitude:&lt;/strong&gt; 4.2&lt;br&gt;&lt;strong&gt;Depth:&lt;/strong&gt; 650.0 km&lt;/div&gt;`)[0];
#                 popup_70924fe2f417859272214e4aff50fa13.setContent(html_8fa93d189d6b5b2ebe89313175dcf0c1);
#
#
#
#         circle_marker_2a7e158ba487dd166bffd11f1599ee59.bindPopup(popup_70924fe2f417859272214e4aff50fa13)
#         ;
#
#
#
#
#             var circle_marker_1ae6f7187dbe021ee684584054b8292a = L.circleMarker(
#                 [-26.0, 184.1],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#c0392b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e74c3c&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 10.497600000000002, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_46345fafd44676304b64f06fabf1d0a7);
#
#
#         var popup_2345fbdf347b9a4fcab2213c22d635c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_addcd4f0244f8732f969199fd962746c = $(`&lt;div id=&quot;html_addcd4f0244f8732f969199fd962746c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Magnitude:&lt;/strong&gt; 5.4&lt;br&gt;&lt;strong&gt;Depth:&lt;/strong&gt; 42.0 km&lt;/div&gt;`)[0];
#                 popup_2345fbdf347b9a4fcab2213c22d635c9.setContent(html_addcd4f0244f8732f969199fd962746c);
#
#
#
#         circle_marker_1ae6f7187dbe021ee684584054b8292a.bindPopup(popup_2345fbdf347b9a4fcab2213c22d635c9)
#         ;
#
#
#
#
#             var circle_marker_8d0c1e65879c1aea379e7f7689fb76cd = L.circleMarker(
#                 [-17.97, 181.66],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffda79&quot;, &quot;dashArray&quot;: n
